# %%
n=6
edge = [[3, 6], [4, 3], [3, 2], [1, 3], [1, 2], [2, 4], [5, 2]]

for temp in edge:
    if 1 in temp: 
        temp.remove(1)
        # print(int(''.join(temp)))
        print(temp)
# Out:
# [3]
# [2]

# %%
for temp in edge:

# %%
def solution(n, edge):
    answer = 0
    return answer

# %%
n=6
edge = [[3, 6], [4, 3], [3, 2], [1, 3], [1, 2], [2, 4], [5, 2]]
solution(n, edge)
